# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df =pd.read_csv('SEC1/CCP/CCP.BK.csv')
df.sample(5)
# Out:
#             Date  Open  High   Low  Close  Adj Close     Volume
# 524    2/23/2016  0.80  0.81  0.79   0.81       0.74  5066600.0
# 1167  10/11/2018  0.43  0.43  0.41   0.41       0.40  4579300.0
# 1015   2/28/2018  0.48  0.48  0.46   0.48       0.47  3469500.0
# 616    7/13/2016  0.80  0.81  0.79   0.80       0.75  4457400.0
# 1090   6/21/2018  0.42  0.43  0.41   0.41       0.40  5152300.0

# %%
# %config InlineBackend.figure_format = 'retina'
df.plot.scatter(x='Open' , y='Low')
plt.title("Close")
# Out:
# Text(0.5, 1.0, 'Close')
